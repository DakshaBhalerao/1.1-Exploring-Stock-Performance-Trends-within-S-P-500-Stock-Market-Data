# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# all_data = pd.read_csv(r'D:\Python\Project2/analysis1.csv')
all_data = pd.read_pickle('analysis1.pkl')

# %%
all_data
# Out:
#            date     open    high       low   close    volume  Name
# 0    2013-02-08   27.350   27.71   27.3100   27.55  33318306  MSFT
# 1    2013-02-11   27.650   27.92   27.5000   27.86  32247549  MSFT
# 2    2013-02-12   27.880   28.00   27.7500   27.88  35990829  MSFT
# 3    2013-02-13   27.930   28.11   27.8800   28.03  41715530  MSFT
# 4    2013-02-14   27.920   28.06   27.8700   28.04  32663174  MSFT
# ...         ...      ...     ...       ...     ...       ...   ...
# 5031 2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL
# 5032 2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL
# 5033 2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL
# 5034 2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL
# 5035 2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL
#
# [5036 rows x 7 columns]

# %%
all_data.dtypes
# Out:
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# Name              object
# dtype: object

# %%
tech_list = all_data['Name'].unique()

# %% [markdown]
# ## Analyze the moving average of various stocks

# %%
all_data['close']
# Out:
# 0        27.55
# 1        27.86
# 2        27.88
# 3        28.03
# 4        28.04
#          ...
# 5031    167.78
# 5032    160.50
# 5033    156.49
# 5034    163.03
# 5035    159.54
# Name: close, Length: 5036, dtype: float64

# %%
# all_data.rolling?

# %%
all_data['close'].rolling(window = 10).mean().head(14)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     27.8535
# 10    27.8355
# 11    27.7865
# 12    27.7795
# 13    27.7565
# Name: close, dtype: float64

# %%
new_data = all_data.copy()

# %%
new_data
# Out:
#            date     open    high       low   close    volume  Name
# 0    2013-02-08   27.350   27.71   27.3100   27.55  33318306  MSFT
# 1    2013-02-11   27.650   27.92   27.5000   27.86  32247549  MSFT
# 2    2013-02-12   27.880   28.00   27.7500   27.88  35990829  MSFT
# 3    2013-02-13   27.930   28.11   27.8800   28.03  41715530  MSFT
# 4    2013-02-14   27.920   28.06   27.8700   28.04  32663174  MSFT
# ...         ...      ...     ...       ...     ...       ...   ...
# 5031 2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL
# 5032 2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL
# 5033 2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL
# 5034 2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL
# 5035 2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL
#
# [5036 rows x 7 columns]

# %%
ma_day = [10,20,30]

for m in ma_day:
    new_data['close'+str(m)] = new_data['close'].rolling(window = m).mean()

# %%
new_data.tail(10)
# Out:
#            date     open      high       low   close    volume  Name  close10  \
# 5026 2018-01-25  174.505  174.9500  170.5300  171.11  41529004  AAPL  176.475
# 5027 2018-01-26  172.000  172.0000  170.0600  171.51  39143011  AAPL  176.098
# 5028 2018-01-29  170.160  170.1600  167.0700  167.96  50640406  AAPL  175.185
# 5029 2018-01-30  165.525  167.3700  164.7000  166.97  46048185  AAPL  174.263
# 5030 2018-01-31  166.870  168.4417  166.5000  167.43  32478930  AAPL  173.096
# 5031 2018-02-01  167.165  168.6200  166.7600  167.78  47230787  AAPL  171.948
# 5032 2018-02-02  166.000  166.8000  160.1000  160.50  86593825  AAPL  170.152
# 5033 2018-02-05  159.100  163.8800  156.0000  156.49  72738522  AAPL  168.101
# 5034 2018-02-06  154.830  163.7200  154.0000  163.03  68243838  AAPL  166.700
# 5035 2018-02-07  163.085  163.4000  159.0685  159.54  51608580  AAPL  165.232
#
#        close20     close30
# 5026  174.5575  174.240333
# 5027  174.6030  174.234000
# ...

# %%
#using pandas plot instead of matplotlib for this only change we need to do is we need to set date as index

# %%
new_data.set_index('date',inplace=True)

# %%
new_data
# Out:
#                open    high       low   close    volume  Name  close10  \
# date
# 2013-02-08   27.350   27.71   27.3100   27.55  33318306  MSFT      NaN
# 2013-02-11   27.650   27.92   27.5000   27.86  32247549  MSFT      NaN
# 2013-02-12   27.880   28.00   27.7500   27.88  35990829  MSFT      NaN
# 2013-02-13   27.930   28.11   27.8800   28.03  41715530  MSFT      NaN
# 2013-02-14   27.920   28.06   27.8700   28.04  32663174  MSFT      NaN
# ...             ...     ...       ...     ...       ...   ...      ...
# 2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL  171.948
# 2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL  170.152
# 2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL  168.101
# 2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL  166.700
# 2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL  165.232
#
#              close20     close30
# date
# 2013-02-08       NaN         NaN
# 2013-02-11       NaN         NaN
# ...

# %%
new_data.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'Name', 'close10', 'close20',
#        'close30'],
#       dtype='object')

# %%
plt.figure(figsize=(20,12))

for index , company in enumerate(tech_list,1):
    plt.subplot(2,2,index)
    filter2 = new_data['Name'] == company
    df2 = new_data[filter2]
    df2[['close10', 'close20', 'close30']].plot(ax = plt.gca())
    plt.title(company)

# %%
all_data.to_csv(r'D:\Python\Project2/analysis2.csv', index = False)
all_data.to_pickle('analysis2.pkl')
