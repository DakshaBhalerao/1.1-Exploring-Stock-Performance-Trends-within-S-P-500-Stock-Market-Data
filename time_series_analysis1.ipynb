# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import glob

# %%
# glob.glob?

# %%
glob.glob(r"D:\Python\Project2\individual_stocks_5yr/*csv")
# Out:
# ['D:\\Python\\Project2\\individual_stocks_5yr\\AAL_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\AAPL_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\AAP_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ABBV_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ABC_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ABT_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ACN_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ADBE_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ADI_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ADM_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ADP_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ADSK_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\ADS_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\AEE_data.csv',
#  'D:\\Python\\Project2\\individual_stocks_5yr\\AEP_data.csv',
# ...

# %%
len(glob.glob(r"D:\Python\Project2\individual_stocks_5yr/*csv"))
# Out:
# 505

# %%
company_list = [r'D:\\Python\\Project2\\individual_stocks_5yr\\AAPL_data.csv',
                r'D:\\Python\\Project2\\individual_stocks_5yr\\AMZN_data.csv',
                r'D:\\Python\\Project2\\individual_stocks_5yr\\GOOGL_data.csv',
                r'D:\\Python\\Project2\\individual_stocks_5yr\\MSFT_data.csv']

# %%
all_data = pd.DataFrame()

for file in company_list:
    current_df = pd.read_csv(file)
    all_data =  pd.concat([current_df,all_data], ignore_index = True)

# %%
all_data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name'], dtype='object')

# %%
all_data['Name'].unique()
# Out:
# array(['MSFT', 'GOOGL', 'AMZN', 'AAPL'], dtype=object)

# %%
all_data.shape
# Out:
# (5036, 7)

# %% [markdown]
# ## Q1 what was the change in price of the stock overtime

# %%
# check if we have any missing values

all_data.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
# check the data types

all_data.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
# as date cannot be of type string object therefore we will need to convert it to datatime 

all_data['date'] =  pd.to_datetime(all_data['date'])

# %%
tech_list = all_data['Name'].unique()

# %%
tech_list
# Out:
# array(['MSFT', 'GOOGL', 'AMZN', 'AAPL'], dtype=object)

# %%
plt.figure(figsize=(16,8))

for index , company in enumerate(tech_list , 1):
    plt.subplot(2 , 2 , index) ## creating subplot for each stock
    filter1 = all_data['Name']==company
    df = all_data[filter1]
    plt.plot(df['date'] , df['close']) ## plotting "date" vs "close"
    plt.title(company)

# %%
# plt.figure?

# %%
all_data.to_csv(r'D:\Python\Project2/analysis1.csv', index = False)
all_data.to_pickle('analysis1.pkl')
